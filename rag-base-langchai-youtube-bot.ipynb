# %%
import os 
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# %pip install -q \
youtube-transcript-api \
langchain-community \
langchain-google-genai \
faiss-cpu \
tiktoken \
python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.
# d:\Agenti Ai\Langchain campusX\.venv\Scripts\python.exe: No module named pip

# %%
import sys
# !{sys.executable} -m pip install youtube-transcript-api
# Out:
# 'd:\Agenti' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_google_genai import (
    GoogleGenerativeAIEmbeddings,
    ChatGoogleGenerativeAI
)
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
#       2 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       3 from langchain_google_genai import (
#       4     GoogleGenerativeAIEmbeddings,
#       5     ChatGoogleGenerativeAI
#       6 )
#
# ModuleNotFoundError: No module named 'youtube_transcript_api'

# %%
import sys
print(sys.executable)
# Out:
# d:\Agenti Ai\Langchain campusX\.venv\Scripts\python.exe

# %%
import sys
# !{sys.executable} -m pip install youtube-transcript-api
# Out:
# 'd:\Agenti' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
#       2 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       3 from langchain_openai import OpenAIEmbeddings, ChatOpenAI
#
# ModuleNotFoundError: No module named 'youtube_transcript_api'
