# %% [markdown]
# ## Using langchaIN chatgpt

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()

model = ChatOpenAI(model='gpt-4', temperature=1.5, max_completion_tokens=10)

result = model.invoke("Write a 5 line poem on cricket")

print(result.content)

# %%
# using llm model intigrate open ai
from langchain_openai import OpenAI
from dotenv import load_dotenv

load_dotenv()

llm = OpenAI(model='gpt-3.5-turbo-instruct')

result = llm.invoke("What is the capital of India")

print(result)

# %% [markdown]
# # Using Groq API intigrating model llms chatmodel

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()

model = ChatGroq(model="llama-3.3-70b-versatile", temperature=1.5)

result = model.invoke("Write a 5 line poem on cricket")

print(result.content)
# Out:
# On the pitch, the batsman stands tall,
# The bowler's seam, a challenging call.
# The cricket ball, a symphony plays,
# As willow meets leather in joyful sways,
# The thrill of the game, forever to enthrall.

# %% [markdown]
# ## using langchain to create a chatr model with google genmini

# %%
from langchain_google_genai import GoogleGenerativeAI
from dotenv import load_dotenv

load_dotenv()

llm = GoogleGenerativeAI(model="gemini-2.5-flash")

result = llm.invoke("What is the capital of India")

print(result)
# Out:
# The capital of India is **New Delhi**.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

response = model.invoke("write h story line about a person who is a time traveler in 10 lines?")
print(response.content)
# Out:
# Here's a 10-line story outline about a time traveler:
#
# 1.  **Elara Vance**, a historian from 2242, secretly develops a temporal displacement unit.
# 2.  Driven by a forgotten family legend, she begins meticulously exploring ancient eras.
# 3.  Her strict rule: observe only, never interfere, to protect the delicate fabric of time.
# 4.  During a visit to ancient Rome, she witnesses an anomaly – a modern object in a mosaic.
# 5.  This discovery reveals another time traveler, actively altering history for unknown gains.
# 6.  Elara's non-interference vow is shattered as she sees ripple effects threatening her own present.
# 7.  She embarks on a desperate chase across millennia, trying to undo subtle but critical changes.
# 8.  Her pursuit leads her to a future cult, worshipping the "Architect" who reshapes history.
# 9.  Elara confronts the Architect, only to uncover a shocking personal connection to their agenda.
# ...

# %% [markdown]
# ## using the Antropic model create a simple chat model

# %%
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv

load_dotenv()

model = ChatAnthropic(model='claude-3-5-sonnet', temperature=1.5, max_completion_tokens=10)

result = model.invoke("Write a 5 line poem on cricket")

print(result.content)
